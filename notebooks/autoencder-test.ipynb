# %%
import os
import sys
import numpy as np
import pytorch_lightning as pl
from PIL import Image
from matplotlib import pyplot as plt
src_path = os.path.join(os.curdir, "..")
sys.path.append(os.path.normpath(src_path))

# %%
root_dir = os.path.join(os.curdir, "..")
data_dir = os.path.join(root_dir, "data", "processed", "test", "images")

# %%
sample_path = os.path.join(data_dir, os.listdir(data_dir)[10])

# %%
image_arr = np.array(Image.open(sample_path))

# %%
fig, ax = plt.subplots(figsize=(15, 12))
ax.imshow(image_arr, cmap="gray")

fig.show()
